# %% [markdown]
# <a href="https://colab.research.google.com/github/syejin2004/2024-1-my-BDA/blob/main/inclass/06w_0409_A_ch07_missingvalue_outlier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **빅데이터분석프로그래밍**

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns

print(sys.version)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 2.0.3
# 1.25.2
# 0.13.1

# %%
# !pip install koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize_matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
# 데이터프레임의 소수점 이하 n(2)자리 출력 설정
pd.set_option('display.precision', 2)

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10, 5, -3, 1])
plt.title('그래프 제목')
plt.xlabel('직선')
plt.show()

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 3.97 MiB/s, done.

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %% [markdown]
# ## 07 데이터 정제- 빠진 데이터, 이상한 데이터 제거하기

# %% [markdown]
# ### 결측지 찾기

# %% [markdown]
# #### 데이터 프레임을 주고 반대로 코드를 짜보는 문제도 나온다.

# %% [markdown]
# #### 빠진데이터(결측값) :  np.nan, None

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'sex'   : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %% [markdown]
# ### 결측치 확인하기 pd.isna() 시험 문제 무조건!!!!!!!!!!!!!

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isnull()  #결측치 확인 isna=isnull
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.notna()    #결측치 값이 False
# Out:
#      sex  score
# 0   True   True
# 1   True   True
# 2  False   True
# 3   True   True
# 4   True  False

# %%
df.notnull()
# Out:
#      sex  score
# 0   True   True
# 1   True   True
# 2  False   True
# 3   True   True
# 4   True  False

# %% [markdown]
# ####  isna() = isnull()!!!!!!!!!!!!!!!!!!!
# ####     notna() = notnull()!!!!!!!!!!!

# %%
df.isna().sum()    #True=1, False=0    열로 계산
# Out:
# sex      1
# score    1
# dtype: int64

# %%
df.notna().sum()
# Out:
# sex      4
# score    4
# dtype: int64

# %%
df.isna().sum(axis=1)   #행으로 계산
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# dtype: int64

# %% [markdown]
# #### df.isna().sum(axis=0)!!!!!!!!!!!!
# #### df.isna().sum(axis=1)!!!!!!!!!!!!

# %%
s = pd.Series([True, False, True, False])
s
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s.sum()
# Out:
# 2

# %%
s.any()  #하나만 true면 true!!!!!!!
# Out:
# True

# %%
s.all()    #모두 다 true면 true!!!!!!!!
# Out:
# False

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.isna().any()
# Out:
# sex      True
# score    True
# dtype: bool

# %%
df.isna().any(axis=1)  #행별로 계산
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
b = df.isna().any(axis=1)
b
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df[b]
# Out:
#    sex  score
# 2  NaN    3.0
# 4    F    NaN

# %%
df[df.isna().any(axis=1)]  #적어도 하나 이상 NaN인 행을 추출, 시험예상!!!!!!!!!!!!!!!
# Out:
#    sex  score
# 2  NaN    3.0
# 4    F    NaN

# %%
df[~df.isna().any(axis=1)]   #NaN이 하나도 없는 행을 추출, 시험예상!!!!!!!!!!!!
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df[df.notna().all(axis=1)] #NaN이 하나도 없는 행을 추출, 시험예상!!!!!!!!!!!!
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %% [markdown]
# ### 결측값 시각화

# %% [markdown]
# *  [패키지 missingno](https://github.com/ResidentMario/missingno)

# %%
df.isnull()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
import seaborn as sns
sns.heatmap(df.isnull());

# %%
sns.heatmap(df.isnull(), cbar=False);

# %%
import missingno as msno
msno.matrix(df);

# %%
tdf = sns.load_dataset('titanic')
msno.matrix(tdf);

# %%
tdf2 = tdf.sample(20)
tdf2
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 814         0       3    male  30.5      0      0    8.05        S   Third
# 92          0       1    male  46.0      1      0   61.17        S   First
# 503         0       3  female  37.0      0      0    9.59        S   Third
# 247         1       2  female  24.0      0      2   14.50        S  Second
# 564         0       3  female   NaN      0      0    8.05        S   Third
# 537         1       1  female  30.0      0      0  106.42        C   First
# 837         0       3    male   NaN      0      0    8.05        S   Third
# 517         0       3    male   NaN      0      0   24.15        Q   Third
# 616         0       3    male  34.0      1      1   14.40        S   Third
# 350         0       3    male  23.0      0      0    9.22        S   Third
# 515         0       1    male  47.0      0      0   34.02        S   First
# 737         1       1    male  35.0      0      0  512.33        C   First
# 82          1       3  female   NaN      0      0    7.79        Q   Third
# 245         0       1    male  44.0      2      0   90.00        Q   First
# 834         0       3    male  18.0      0      0    8.30        S   Third
# 452         0       1    male  30.0      0      0   27.75        C   First
# 740         1       1    male   NaN      0      0   30.00        S   First
# 354         0       3    male   NaN      0      0    7.22        C   Third
# 395         0       3    male  22.0      0      0    7.80        S   Third
# 780         1       3  female  13.0      0      0    7.23        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 814    man        True  NaN  Southampton    no   True
# 92     man        True    E  Southampton    no  False
# 503  woman       False  NaN  Southampton    no   True
# 247  woman       False  NaN  Southampton   yes  False
# 564  woman       False  NaN  Southampton    no   True
# 537  woman       False  NaN    Cherbourg   yes   True
# 837    man        True  NaN  Southampton    no   True
# 517    man        True  NaN   Queenstown    no   True
# 616    man        True  NaN  Southampton    no  False
# 350    man        True  NaN  Southampton    no   True
# 515    man        True    D  Southampton    no   True
# 737    man        True    B    Cherbourg   yes   True
# 82   woman       False  NaN   Queenstown   yes   True
# 245    man        True    C   Queenstown    no  False
# 834    man        True  NaN  Southampton    no   True
# 452    man        True    C    Cherbourg    no   True
# 740    man        True    D  Southampton   yes   True
# 354    man        True  NaN    Cherbourg    no   True
# 395    man        True  NaN  Southampton    no   True
# 780  child       False  NaN    Cherbourg   yes   True

# %%
msno.matrix(tdf2);

# %% [markdown]
# - 오른쪽의 스파크라인은 데이터 완성도의 일반적인 모양을 요약하고 데이터 세트에서 최대 및 최소 널링이 있는 행을 가리킵니다.
#     - 행마다 15개중 naN이 아닌 유효한 데이터의 갯수를 나타내고
#     -그 점을 다음 행과 연결한 선

# %%
# 열 embarked이 NaN인 행 추출
tdf[ tdf.embarked.isna() ]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
# 두 열, age, deck이 모두 NaN인 행 추출
tdf[(tdf.age.isna()) & (tdf.deck.isna()) ]
# Out:
#      survived  pclass     sex  age  sibsp  parch   fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.46        Q   Third
# 17          1       2    male  NaN      0      0  13.00        S  Second
# 19          1       3  female  NaN      0      0   7.22        C   Third
# 26          0       3    male  NaN      0      0   7.22        C   Third
# 28          1       3  female  NaN      0      0   7.88        Q   Third
# ..        ...     ...     ...  ...    ...    ...    ...      ...     ...
# 859         0       3    male  NaN      0      0   7.23        C   Third
# 863         0       3  female  NaN      8      2  69.55        S   Third
# 868         0       3    male  NaN      0      0   9.50        S   Third
# 878         0       3    male  NaN      0      0   7.90        S   Third
# 888         0       3  female  NaN      1      2  23.45        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 5      man        True  NaN   Queenstown    no   True
# 17     man        True  NaN  Southampton   yes   True
# 19   woman       False  NaN    Cherbourg   yes   True
# 26     man        True  NaN    Cherbourg    no   True
# 28   woman       False  NaN   Queenstown   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [158 rows x 15 columns]

# %%
# 세개열, age, deck, embark_town이 모두 NaN인 행 추출
tdf[(tdf.age.isna()) & (tdf.deck.isna()) & (tdf.embark_town.isna()) ]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
 # 최소한 1개의 NaN에 있는 행 추출
 tdf[ tdf.isna( ).any(axis=1) ]
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.25        S   Third
# 2           1       3  female  26.0      0      0   7.92        S   Third
# 4           0       3    male  35.0      0      0   8.05        S   Third
# 5           0       3    male   NaN      0      0   8.46        Q   Third
# 7           0       3    male   2.0      3      1  21.07        S   Third
# ..        ...     ...     ...   ...    ...    ...    ...      ...     ...
# 884         0       3    male  25.0      0      0   7.05        S   Third
# 885         0       3  female  39.0      0      5  29.12        Q   Third
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [709 rows x 15 columns]

# %%
msno.bar(tdf);

# %% [markdown]
# ### 결측치 제거하기

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna()   #NaN 제거
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %% [markdown]
# *   subset : 열 레이블 또는 레이블 시퀀스(선택 사항)
# *    예를 들어 행을 드롭하는 경우, 다른 축인 열을 지정하면 그열에 null이 있는 행을 제거

# %%
df.dropna(subset = ['score'])  #score에 null이 있으면 제거
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df.dropna(subset = ['sex'])  #sex에 null이 있으면 제거
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0
# 4   F    NaN

# %%
df_nomiss = df.dropna(subset = ['score'])
df_nomiss
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss['score']+1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df.dropna(subset = ['sex'], axis=0)
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0
# 4   F    NaN

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
# 행 2에 NaN이 있으면 열을 제거
df.dropna(subset = [2], axis=1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %%
# 행 3에 NaN이 있으면 열을 제거
df.dropna(subset = [3], axis=1)
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
# 행 4에 NaN이 있으면 열을 제거
df.dropna(subset = [4], axis=1)
# Out:
#    sex
# 0    M
# 1    F
# 2  NaN
# 3    M
# 4    F

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(axis=1).empty
# Out:
# True

# %%
df['score'].mean()  #결측값은 제거(무시)하고 계산
# Out:
# 4.0

# %%
df['score'].sum()
# Out:
# 16.0

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score  = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %% [markdown]
# ### pandas 문서

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman', np.NaN],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip', np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT, pd.NaT]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT

# %%
df.isna()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True
# 3   True   True   True

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(axis=1) # axis = 'columns'
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
#하나라도 NaN인 경우, 행 제거
df.dropna(how = 'any')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
#모든 값이 NaN인 경우, 행 제거
df.dropna(how = 'all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %% [markdown]
# ### 결측치 대체하기

# %% [markdown]
# #### 평균값으로 결측치 대체하기

# %%
exam = pd.read_csv('data/exam.csv')      # 데이터 불러오기
exam.loc[[2, 7, 14], ['math']] = np.nan  # 2, 7, 14행의 math에 NaN 할당
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']]  #dataframe
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
exam.loc[[2, 7, 14], 'math']  #series
# Out:
# 2    NaN
# 7    NaN
# 14   NaN
# Name: math, dtype: float64

# %%
exam.math.mean()
# Out:
# 55.23529411764706

# %% [markdown]
# ### 결측값 채워넣기 fillna()

# %%
exam['math'] = exam['math'].fillna(100)  # math가 NaN이면 100으로 대체
exam                                    # 출력
# Out:
#     id  nclass   math  english  science
# 0    1       1   50.0       98       50
# 1    2       1   60.0       97       60
# 2    3       1  100.0       86       78
# 3    4       1   30.0       98       58
# 4    5       2   25.0       80       65
# 5    6       2   50.0       89       98
# 6    7       2   80.0       90       45
# 7    8       2  100.0       78       25
# 8    9       3   20.0       98       15
# 9   10       3   50.0       98       45
# 10  11       3   65.0       65       65
# 11  12       3   45.0       85       32
# 12  13       4   46.0       98       65
# 13  14       4   48.0       87       12
# 14  15       4  100.0       56       78
# 15  16       4   58.0       98       65
# 16  17       5   65.0       68       98
# 17  18       5   80.0       78       90
# 18  19       5   89.0       68       87
# 19  20       5   78.0       83       58

# %%
exam = pd.read_csv('data/exam.csv')      # 데이터 불러오기
exam.loc[[2, 7, 14], ['math']] = np.nan  # 2, 7, 14행의 math에 NaN 할당
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
pd.set_option('display.precision', 3)  #소수점 3번째자리까지 표시

m = exam['math'].mean()
exam['math'] = exam['math'].fillna(m)  # math가 NaN이면 55.23529411764706로 대체
exam
# Out:
#     id  nclass    math  english  science
# 0    1       1  50.000       98       50
# 1    2       1  60.000       97       60
# 2    3       1  55.235       86       78
# 3    4       1  30.000       98       58
# 4    5       2  25.000       80       65
# 5    6       2  50.000       89       98
# 6    7       2  80.000       90       45
# 7    8       2  55.235       78       25
# 8    9       3  20.000       98       15
# 9   10       3  50.000       98       45
# 10  11       3  65.000       65       65
# 11  12       3  45.000       85       32
# 12  13       4  46.000       98       65
# 13  14       4  48.000       87       12
# 14  15       4  55.235       56       78
# 15  16       4  58.000       98       65
# 16  17       5  65.000       68       98
# 17  18       5  80.000       78       90
# 18  19       5  89.000       68       87
# 19  20       5  78.000       83       58

# %% [markdown]
# ### 07-2 이상한 데이터를 찾아라 - 이상치 정제하기

# %%
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts()
# Out:
# sex
# 1.0    3
# 2.0    2
# Name: count, dtype: int64

# %%
df['score'].value_counts()
# Out:
# score
# 4    2
# 5    1
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
# sex가 3이면 NaN 부여
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
# score가 5보다 크면 NaN 부여
df['score'] = np.where(df['score'] > 5, np.nan, df['score'])
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
# sex, score 결측치 제거, sex별 분리, score 평균구하기
df.dropna(subset = ['sex', 'score']).groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df.dropna().groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 10, np.nan)  # 조건에 맞으면 문자 부여
df
# Out:
#    x1    x2
# 0   1  10.0
# 1   1  10.0
# 2   2   NaN
# 3   2   NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  etc
# 3   2  etc

# %%
# 'etc'를 NaN으로 바꾸기
df['x2'] = df['x2'].replace('etc', np.nan)
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  NaN
# 3   2  NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %% [markdown]
# ### 이상치 제거하기 - 극단적인 값

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(5)
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 171       subaru  impreza awd    2.5  2008    4  manual(m5)   4   19   25  p
# 145       nissan       altima    3.5  2008    6  manual(m6)   f   19   27  p
# 158      pontiac   grand prix    5.3  2008    8    auto(s4)   f   16   25  p
# 223   volkswagen   new beetle    2.0  1999    4  manual(m5)   f   21   29  r
# 99         honda        civic    1.6  1999    4  manual(m5)   f   28   33  r
#
#        category
# 171     compact
# 145     midsize
# 158     midsize
# 223  subcompact
# 99   subcompact

# %%
import seaborn as sns
sns.boxplot(mpg, y = 'hwy');

# %%
mpg.hwy.describe()
# Out:
# count    234.000
# mean      23.440
# std        5.955
# min       12.000
# 25%       18.000
# 50%       24.000
# 75%       27.000
# max       44.000
# Name: hwy, dtype: float64

# %%
s = pd.Series([1, 2, 3, 4, 5])

# %%
s.quantile([.25, .50, .75])
# Out:
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# dtype: float64

# %%
s2 = pd.Series([1, 2, 4, 5])

# %%
s2.quantile([.25, .50, .75])
# Out:
# 0.25    1.75
# 0.50    3.00
# 0.75    4.25
# dtype: float64

# %%
pct25, pct75 = mpg['hwy'].quantile([.25, .75])

# %%
pct25
# Out:
# 18.0

# %%
pct75
# Out:
# 27.0

# %% [markdown]
# #### IQR(interquartile range) 구하기

# %%
iqr = pct75 - pct25
iqr
# Out:
# 9.0

# %% [markdown]
# #### 하한, 상한 구하기

# %%
pct25 - 1.5 * iqr  # 하한
# Out:
# 4.5

# %%
pct75 + 1.5 * iqr  # 상한
# Out:
# 40.5

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
import missingno as msno
msno.matrix(mpg);

# %%
dmpg = mpg.dropna(subset = ['hwy'])
len(dmpg)
# Out:
# 234

# %%
dmpg.shape[1]
# Out:
# 11

# %% [markdown]
# #### 3.이상값을 결측 처리하기

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')

# %%
# 4.5 ~ 40.5 벗어나면 NaN 부여
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])

# 결측치 빈도 확인
mpg['hwy'].isna().sum()
# Out:
# 3

# %%
dmpg.shape
# Out:
# (234, 11)

# %%
dmpg.dropna(subset = ['hwy']).groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      28.160
# r      21.000

# %%
mpg.dropna(subset = ['hwy']).groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      27.728
# r      21.000

# %%
dmpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      28.160
# r      21.000

# %%
mpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      27.728
# r      21.000

# %% [markdown]
# ## 정리하기

# %%
## 1. 결측치 정제하기
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
pd.isna(df).sum()                                 # 결측치 확인
df_nomiss = df.dropna(subset = ['score'])         # 결측치 제거
df_nomiss = df.dropna(subset = ['score', 'sex'])  # 여러 변수 동시에 결측치 제거


## 2. 이상치 정제하기

# 이상치 확인
df['sex'].value_counts(sort = False)

# 이상치 결측 처리
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])

# 상자 그림으로 극단치 기준값 찾기
pct25 = mpg['hwy'].quantile(.25)  # 1사분위수
pct75 = mpg['hwy'].quantile(.75)  # 3사분위수
iqr = pct75 - pct25               # IQR
pct25 - 1.5 * iqr                 # 하한
pct75 + 1.5 * iqr                 # 상한

# 극단치 결측 처리
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])
